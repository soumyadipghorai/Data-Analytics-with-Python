# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import poisson

# %% [markdown]
# <img src = "https://www.onlinemathlearning.com/image-files/poisson-distribution-formula.png">

# %%
poisson.pmf(3, 2) # x = 3, mean = 2
# Out:
# 0.18044704431548356

# %% [markdown]
# Suppose bank customers arrive randomly on weekday afternoons at an average of 3.2 customers every 4mins. Whats the probabililty of exactly 5 customers arriving in a 4min interval on a weekday afternoon.

# %%
lmda = 3.2
print(poisson.pmf(5, lmda))
# Out:
# 0.11397938346351824

# %% [markdown]
# Suppose bank customers arrive randomly on weekday afternoons at an average of 3.2 customers every 4mins. Whats the probabililty of having more than 7 customers arriving in a 4min interval on a weekday afternoon.

# %%
# P(X > 7) = 1 - P(X<=7)
lmda = 3.2
prob = 0
for i in range(8) :
    prob += poisson.pmf(i, lmda)

print(1 - prob)
# Out:
# 0.016829841748957852

# %% [markdown]
# Suppose bank customers arrive randomly on weekday afternoons at an average of 3.2 customers every 4mins. Whats the probabililty of having exactly 10 customers arriving in a 8min interval on a weekday afternoon.

# %%
# !wrong ==> prob > 1
prob = 0
for i in range(11) :
    prob += (poisson.pmf(i, lmda) + poisson.pmf(10 - i, lmda))

print(prob)
# Out:
# 1.9990056643905012

# %%
poisson.pmf(10, 6.4)
# Out:
# 0.052790043854115495

# %% [markdown]
# #### change of poisson distribution with change in sample size

# %%
for i in range(6) :
    sample = np.random.poisson(lam = 5, size = 10 * pow(10, i))
    sns.histplot(sample);
    plt.show();

# %% [markdown]
# #### change of poisson distribution with change in lambda
#
# <img src='https://www.scribbr.nl/wp-content/uploads/2022/08/Poisson-distribution-graph.webp' width = 400>

# %%
for i in range(10) :
    sample = np.random.poisson(lam = 0.5+ (i*2), size = 100000)
    print('lambda --> ',0.5+ (i*2))
    sns.histplot(sample, stat= 'probability', bins= 30, kde = True)
    plt.xlim(0 , 50)
    plt.ylim(0 , 0.6)
    plt.show()
# Out:
# lambda -->  0.5
# lambda -->  2.5
# lambda -->  4.5
# lambda -->  6.5
# lambda -->  8.5
# lambda -->  10.5
# lambda -->  12.5
# lambda -->  14.5
# lambda -->  16.5
# lambda -->  18.5

# %%
for i in range(10) :
    sample = np.random.poisson(lam = 0.5+ (i*2), size = 100000)
    print('lambda --> ',0.5+ (i*2))
    sns.histplot(sample, stat= 'probability', bins= 30, kde = True)
    plt.xlim(0 , 50)
    plt.ylim(0 , 0.6)
    plt.show()
# Out:
# lambda -->  0.5
# lambda -->  2.5
# lambda -->  4.5
# lambda -->  6.5
# lambda -->  8.5
# lambda -->  10.5
# lambda -->  12.5
# lambda -->  14.5
# lambda -->  16.5
# lambda -->  18.5
