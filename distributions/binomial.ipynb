# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import binom

# %% [markdown]
# <img src='https://www.gstatic.com/education/formulas2/553212783/en/binomial_distribution_formula.svg'>
#
# ```
# P	=	binomial probability
# x	=	number of times for a specific outcome within n trials
# (n x)	=	number of combinations
# p	=	probability of success on a single trial
# q	=	probability of failure on a single trial
# n	=	number of trials
# ```

# %% [markdown]
# A survey found that 65% of all financial consumers were very satisfied with their primary financial institution. Suppose that 25 financial consumers are sampled and if survey result still holds true today, what is the probability that exactly 19 are very satisfied with their primary financial institute?

# %%
p = 0.65
# P(x = 19)

# 25C19*P^19*(1-P)^25-19
print(binom.pmf(k = 19, n = 25, p=p))
# Out:
# 0.090777998593228

# %% [markdown]
# According to the US census Bureau approx 6% of all workers in Jackson, MIssissippi are unemployed. In conducting a random telephone survey in Jackson, what is the prob of getting two or fewer unemployed workers in a sample of 20?

# %%
p = 0.06

# p ( X <= 2) = P(X=0) + P(X=1) + P(X=2)
prob = 0
for i in range(3) :
    prob += binom.pmf(k = i, n = 20, p = p)

print('using pmf --> ', prob)

print('using cdf --> ', binom.cdf(k = 2, n = 20, p = p))
# Out:
# using pmf -->  0.8850275957378543
# using cdf -->  0.8850275957378549

# %% [markdown]
# Solve the binomial probability for n = 20, p = 0.4 and x = 10

# %%
print(binom.pmf(k = 10, n = 20, p = 0.4))
# Out:
# 0.11714155053639005

# %%
# binomial distribution has 2 parameters n and p 
np.random.binomial(n = 100, p = 0.05, size = 20)
# Out:
# array([ 8,  3,  5, 10,  9,  5,  5,  3,  5,  4,  8,  4,  4,  4,  5,  5,  2,
#         7,  5,  9])

# %% [markdown]
# #### change of binomial distribution with change in sample size

# %%
for i in range(5) :
    sample = np.random.binomial(n = 100, p = 0.05, size = 10 * pow(10, i))
    sns.histplot(sample);
    print('sample size --> ', 10 * pow(10, i))
    plt.show();
# Out:
# sample size -->  10
# sample size -->  100
# sample size -->  1000
# sample size -->  10000
# sample size -->  100000

# %% [markdown]
# #### change of binomial distribution with change in probability

# %%
for i in range(11) :
    if i < 10 :
        sample = np.random.binomial(n = 100, p = 0.01 + (0.1*i), size = 1000)
        prob = 0.01 + (0.1*i)
    else :
        sample = np.random.binomial(n = 100, p = 0.99, size = 1000)
        prob = 0.99
    sns.histplot(sample, stat= 'probability');
    print('prob --> ', prob)
    plt.xlim(0 , 100)
    plt.ylim(0 , 0.5)
    plt.show();
# Out:
# prob -->  0.01
# prob -->  0.11
# prob -->  0.21000000000000002
# prob -->  0.31000000000000005
# prob -->  0.41000000000000003
# prob -->  0.51
# prob -->  0.6100000000000001
# prob -->  0.7100000000000001
# prob -->  0.81
# prob -->  0.91
# prob -->  0.99

# %%
for i in range(11) :
    if i < 10 :
        sample = np.random.binomial(n = 10+(5*i), p = 0.5, size = 1000)
    sns.histplot(sample, stat= 'probability');
    print('n --> ', 10+(5*i))
    plt.xlim(0 , 50)
    plt.ylim(0 , 0.5)
    plt.show();
# Out:
# n -->  10
# n -->  15
# n -->  20
# n -->  25
# n -->  30
# n -->  35
# n -->  40
# n -->  45
# n -->  50
# n -->  55
# n -->  60
